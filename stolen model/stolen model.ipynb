# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
model = pickle.load(open('model.pickle', 'rb'))

# %%
from sklearn import tree

plt.figure(figsize=(20, 20))
tree.plot_tree(model, fontsize=10, filled=True, class_names=['Donald', 'Justin'])
plt.show()

# %%
from PIL import Image
img = Image.open('AgentSloth.png')
img = np.array(img)
img = np.moveaxis(img, -1, 0)
img = np.ndarray.flatten(img)
img[338852] = 160
img[467989] = 150
img[107727] = 142
img[4005] = 125
img[218068] = 6

img = img.reshape(3, 400, 400)
img = np.moveaxis(img, 0, -1)
ans = Image.fromarray(img)
ans.save("hack.png")
